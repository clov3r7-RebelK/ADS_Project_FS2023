# %% [markdown]
# # Restaurant Kt. Zürich - ADS Project Gruppe 6

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import json
import psycopg2
from aifc import Error
import requests
import folium
import branca
from sqlalchemy import create_engine
from bs4 import BeautifulSoup
import requests
import re
import csv
#import anytree

# %% [markdown]
# ### Code Funktionen

# %%
def get_de(field):
    try:
        return field['de']
    except (KeyError, TypeError):
        try:
            return field['en']
        except (KeyError, TypeError):
            return field

# %% [markdown]
# ### API Preparation und Erstellen DataFrame

# %%
base_url = 'https://www.zuerich.com/en/api/v2/data'
gastronomy_url = base_url+'?id=166'

headers = {'Accept': 'application/json'}
r = requests.get(gastronomy_url, headers=headers)

data = r.json()

#Collect only data with german tags
de_data = [{k: get_de(v) for (k,v) in f.items()} for f in data]


df = pd.DataFrame(de_data)
all_data_de = pd.json_normalize(de_data)

# %%
all_data_de.to_csv('output_api_restaurant.csv', index=False)

# %% [markdown]
# ### Web Scraping von Gastro Zürich

# %%
base_url = 'https://www.tripadvisor.com/Restaurant_Review-g188113-d2621627-Reviews-Brasserie_Louis-Zurich.html'

# Erstelle eine Session und akzeptiere Cookies
session = requests.Session()
session.headers.update({
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
})

# Liste für die Bewertungen
reviews = []

# Starte die Schleife für die Abfragen
for i in range(0, 10):  # Hier kannst du die Anzahl der Abfragen anpassen (in diesem Fall 4)
    if i == 0:
        url = base_url
    else:
        offset = i * 15
        url = base_url.replace('Reviews-', 'Reviews-or{}-'.format(offset))

    # Lade den HTML-Code der Webseite herunter
    response = session.get(url)
    html_content = response.text

    soup = BeautifulSoup(html_content, 'html.parser')
    review_elements = soup.find_all('div', class_='reviewSelector')

    for review_element in review_elements:
        # Restaurant
        restaurant = 'Brasserie Louis'

        # Review
        review_text_element = review_element.find('p', class_='partial_entry')
        if review_text_element:
            review_text = re.sub('<.*?>', '', str(review_text_element))
            review_text = review_text.strip()
        else:
            review_text = ''

        # Points
        points_element = review_element.find('span', class_=re.compile('bubble_([0-9]+)'))
        if points_element:
            points_class = points_element.get('class')[1]
            points = int(re.search(r'\d+', points_class).group())/10
        else:
            points = None
            
        sentiment = 1 if points > 2 else 0

        reviews.append({'Restaurant': restaurant, 'Review': review_text, 'Points': points, 'Sentiment':sentiment})

# Schreibe die Bewertungen in eine CSV-Datei
filename = 'tripadvisor_reviews.csv'

with open(filename, 'w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=['Restaurant', 'Review', 'Points', 'Sentiment'])
    writer.writeheader()
    writer.writerows(reviews)

print('Die Bewertungen wurden in die Datei', filename, 'geschrieben.')
# Out:
# Die Bewertungen wurden in die Datei tripadvisor_reviews.csv geschrieben.

# %% [markdown]
# ## Datenbereinigung

# %%
data_working = all_data_de
data_working.replace('', np.nan, inplace=True)
data_working.replace('None', np.nan, inplace=True)
data_working.replace('[]', np.nan, inplace=True)

#using only relevant rows for the project
data_cleaned_de = data_working.iloc[:, [3, 7, 19, 20, 28, 30, 45, 46, 47, 49, 50, 51, 53, 55, 57, 61, 62]]
data_cleaned_de
# Out:
#     identifier                          name
# 0      1011217     John Baker Bahnhofstrasse  \
# 1      1011192             Restaurant Lennox
# 2      1011149  Swiss Life Arena Gastronomie
# 3      1011103                      MIKURIYA
# 4      1011068                 Bill’s Burger
# ..         ...                           ...
# 243       1574     Carlton Restaurants & Bar
# 244       1524               Brasserie Louis
# 245       1509                Brasserie Lipp
# 246       1501             Brasserie Federal
# 247       1477               Bodega Española
#
#                                                  opens
# 0                                                   []  \
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 243  [Monday, Tuesday, Wednesday, Thursday, Friday,...
# 244  [Monday, Tuesday, Wednesday, Thursday, Friday,...
# 245   [Tuesday, Wednesday, Thursday, Friday, Saturday]
# 246  [Monday, Tuesday, Wednesday, Thursday, Friday,...
# 247  [Monday, Tuesday, Wednesday, Thursday, Friday,...
#
#                                           openingHours
# 0    [Mo,Tu,We,Th,Fr 07:00:00-18:30:00, Sa 08:00:00...  \
# 1    [Mo,Tu,We,Th 11:30:00-22:00:00, Fr 11:30:00-00...
# 2                                                 None
# 3                   [Tu,We,Th,Fr,Sa 19:00:00-00:00:00]
# 4                   [Mo,Tu,We,Th,Fr 11:00:00-14:00:00]
# ..                                                 ...
# 243  [Mo,Tu,We,Th,Fr 11:30:00-00:00:00, Sa 10:30:00...
# 244  [Mo,Tu 17:00:00-22:00:00, We,Th 11:30:00-14:00...
# 245  [Tu,We,Th,Fr 12:00:00-15:00:00, Tu,We,Th,Fr 18...
# 246  [Mo,Tu,We,Su 09:00:00-22:00:00, Th,Fr,Sa 09:00...
# 247           [Mo,Tu,We,Th,Fr,Sa,Su 10:30:00-00:00:00]
#
#                                              image.url
# 0    https://www.zuerich.com/sites/default/files/im...  \
# 1    https://www.zuerich.com/sites/default/files/im...
# 2    https://www.zuerich.com/sites/default/files/im...
# 3    https://www.zuerich.com/sites/default/files/im...
# 4    https://www.zuerich.com/sites/default/files/im...
# ..                                                 ...
# 243  https://www.zuerich.com/sites/default/files/im...
# 244  https://www.zuerich.com/sites/default/files/ke...
# 245  https://www.zuerich.com/sites/default/files/im...
# 246  https://www.zuerich.com/sites/default/files/ke...
# 247  https://www.zuerich.com/sites/default/files/ke...
#
#             image.caption.en  category.Cuisine.swissId
# 0               Crusty bread                       NaN  \
# 1                       None                       NaN
# 2                       None                       NaN
# 3                       None                       NaN
# 4                       None                       NaN
# ..                       ...                       ...
# 243                     None                       NaN
# 244   Brasserie Louis Zurich                       NaN
# 245  Brasserie Lipp Interior                       NaN
# 246                      NaN                       NaN
# 247          Bodega Española                       NaN
#
#     category.International.swissId category.Brunch.swissId
# 0                              NaN                     NaN  \
# 1           culinary-international         culinary-brunch
# 2                              NaN                     NaN
# 3                              NaN                     NaN
# 4                              NaN                     NaN
# ..                             ...                     ...
# 243         culinary-international         culinary-brunch
# 244                            NaN                     NaN
# 245                            NaN         culinary-brunch
# 246                            NaN         culinary-brunch
# 247                            NaN                     NaN
#
#     category.Dinner.swissId  category.Bars & Lounges.swissId
# 0                       NaN                              NaN  \
# 1           culinary-dinner                              NaN
# 2                       NaN                              NaN
# 3           culinary-dinner                              NaN
# 4                       NaN                              NaN
# ..                      ...                              ...
# 243                     NaN                              NaN
# 244         culinary-dinner                              NaN
# 245         culinary-dinner                              NaN
# 246         culinary-dinner                              NaN
# 247         culinary-dinner                              NaN
#
#     category.Italian.swissId category.Gourmet.swissId
# 0                        NaN                      NaN  \
# 1                        NaN                      NaN
# 2           culinary-italian                      NaN
# 3                        NaN         culinary-gourmet
# 4                        NaN                      NaN
# ..                       ...                      ...
# 243                      NaN                      NaN
# 244                      NaN                      NaN
# 245                      NaN                      NaN
# 246                      NaN                      NaN
# 247                      NaN                      NaN
#
#       category.Sushi.swissId category.Vegan friendly.swissId
# 0                        NaN                             NaN  \
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3    culinary-japanese-sushi                             NaN
# 4                        NaN                             NaN
# ..                       ...                             ...
# 243                      NaN                             NaN
# 244                      NaN                             NaN
# 245                      NaN                             NaN
# 246                      NaN                             NaN
# 247                      NaN                             NaN
#
#     category.BBQ.swissId  category.Restaurant Features.swissId
# 0                    NaN                                   NaN
# 1                    NaN                                   NaN
# 2                    NaN                                   NaN
# 3                    NaN                                   NaN
# 4                    NaN                                   NaN
# ..                   ...                                   ...
# 243                  NaN                                   NaN
# 244                  NaN                                   NaN
# 245                  NaN                                   NaN
# 246                  NaN                                   NaN
# 247                  NaN                                   NaN
#
# [248 rows x 17 columns]

# %% [markdown]
# ### Duplikate löschen

# %%
#Duplikate anhand von Namen und geographischer Position eliminieren
#data_prod = data_cleaned_de.drop_duplicates(subset=['name', 'geoCoordinates.latitude', 'geoCoordinates.longitude'])
data_prod = data_cleaned_de

# %% [markdown]
# ## Datenbank

# %%
try:
    # Replace the connection parameters with your database details
    connection = psycopg2.connect(
        user="ads_user",
        password="secPWforADS2023",
        host="localhost",
        port="5432",
        database="ads_proj_db"
    )
    cursor = connection.cursor()
    # Execute a simple query
    cursor.execute("SELECT version();")
    # Fetch the query result
    record = cursor.fetchone()
    print("Connection successful!")
    print("PostgreSQL version:", record[0])
    # Close the cursor and connection
    cursor.close()
    connection.close()
except Error as e:
    print("Error connecting to PostgreSQL database:", e)
# Out:
# Connection successful!
# PostgreSQL version: PostgreSQL 15.3, compiled by Visual C++ build 1914, 64-bit

# %%
conn = psycopg2.connect("host=localhost dbname=ads_proj_db user=ads_user password=secPWforADS2023")

# %%
engine = create_engine('postgresql://ads_user:secPWforADS2023@localhost:5432/ads_proj_db')
data_prod.to_sql('restaurant_data', engine, if_exists='replace')

#cur = conn.cursor()
# Out:
# 248

# %%
my_table = pd.read_sql(''' Select * from restaurant_data ''', conn) 
print(my_table)
# Out:
#      index identifier                          name
# 0        0    1011217     John Baker Bahnhofstrasse  \
# 1        1    1011192             Restaurant Lennox
# 2        2    1011149  Swiss Life Arena Gastronomie
# 3        3    1011103                      MIKURIYA
# 4        4    1011068                 Bill’s Burger
# ..     ...        ...                           ...
# 243    243       1574     Carlton Restaurants & Bar
# 244    244       1524               Brasserie Louis
# 245    245       1509                Brasserie Lipp
# 246    246       1501             Brasserie Federal
# 247    247       1477               Bodega Española
#
#                                                  opens
# 0                                                   {}  \
# 1                                                   {}
# 2                                                   {}
# 3                                                   {}
# 4                                                   {}
# ..                                                 ...
# 243  {Monday,Tuesday,Wednesday,Thursday,Friday,Satu...
# 244  {Monday,Tuesday,Wednesday,Thursday,Friday,Satu...
# 245       {Tuesday,Wednesday,Thursday,Friday,Saturday}
# 246  {Monday,Tuesday,Wednesday,Thursday,Friday,Satu...
# 247  {Monday,Tuesday,Wednesday,Thursday,Friday,Satu...
#
#                                           openingHours
# 0    {"Mo,Tu,We,Th,Fr 07:00:00-18:30:00","Sa 08:00:...  \
# 1    {"Mo,Tu,We,Th 11:30:00-22:00:00","Fr 11:30:00-...
# 2                                                 None
# 3                 {"Tu,We,Th,Fr,Sa 19:00:00-00:00:00"}
# 4                 {"Mo,Tu,We,Th,Fr 11:00:00-14:00:00"}
# ..                                                 ...
# 243  {"Mo,Tu,We,Th,Fr 11:30:00-00:00:00","Sa 10:30:...
# 244  {"Mo,Tu 17:00:00-22:00:00","We,Th 11:30:00-14:...
# 245  {"Tu,We,Th,Fr 12:00:00-15:00:00","Tu,We,Th,Fr ...
# 246  {"Mo,Tu,We,Su 09:00:00-22:00:00","Th,Fr,Sa 09:...
# 247         {"Mo,Tu,We,Th,Fr,Sa,Su 10:30:00-00:00:00"}
#
#                                              image.url
# 0    https://www.zuerich.com/sites/default/files/im...  \
# 1    https://www.zuerich.com/sites/default/files/im...
# 2    https://www.zuerich.com/sites/default/files/im...
# 3    https://www.zuerich.com/sites/default/files/im...
# 4    https://www.zuerich.com/sites/default/files/im...
# ..                                                 ...
# 243  https://www.zuerich.com/sites/default/files/im...
# 244  https://www.zuerich.com/sites/default/files/ke...
# 245  https://www.zuerich.com/sites/default/files/im...
# 246  https://www.zuerich.com/sites/default/files/ke...
# 247  https://www.zuerich.com/sites/default/files/ke...
#
#             image.caption.en category.Cuisine.swissId
# 0               Crusty bread                     None  \
# 1                       None                     None
# 2                       None                     None
# 3                       None                     None
# 4                       None                     None
# ..                       ...                      ...
# 243                     None                     None
# 244   Brasserie Louis Zurich                     None
# 245  Brasserie Lipp Interior                     None
# 246                     None                     None
# 247          Bodega Española                     None
#
#     category.International.swissId category.Brunch.swissId
# 0                             None                    None  \
# 1           culinary-international         culinary-brunch
# 2                             None                    None
# 3                             None                    None
# 4                             None                    None
# ..                             ...                     ...
# 243         culinary-international         culinary-brunch
# 244                           None                    None
# 245                           None         culinary-brunch
# 246                           None         culinary-brunch
# 247                           None                    None
#
#     category.Dinner.swissId category.Bars & Lounges.swissId
# 0                      None                            None  \
# 1           culinary-dinner                            None
# 2                      None                            None
# 3           culinary-dinner                            None
# 4                      None                            None
# ..                      ...                             ...
# 243                    None                            None
# 244         culinary-dinner                            None
# 245         culinary-dinner                            None
# 246         culinary-dinner                            None
# 247         culinary-dinner                            None
#
#     category.Italian.swissId category.Gourmet.swissId
# 0                       None                     None  \
# 1                       None                     None
# 2           culinary-italian                     None
# 3                       None         culinary-gourmet
# 4                       None                     None
# ..                       ...                      ...
# 243                     None                     None
# 244                     None                     None
# 245                     None                     None
# 246                     None                     None
# 247                     None                     None
#
#       category.Sushi.swissId category.Vegan friendly.swissId
# 0                       None                            None  \
# 1                       None                            None
# 2                       None                            None
# 3    culinary-japanese-sushi                            None
# 4                       None                            None
# ..                       ...                             ...
# 243                     None                            None
# 244                     None                            None
# 245                     None                            None
# 246                     None                            None
# 247                     None                            None
#
#     category.BBQ.swissId category.Restaurant Features.swissId
# 0                   None                                 None
# 1                   None                                 None
# 2                   None                                 None
# 3                   None                                 None
# 4                   None                                 None
# ..                   ...                                  ...
# 243                 None                                 None
# 244                 None                                 None
# 245                 None                                 None
# 246                 None                                 None
# 247                 None                                 None
#
# [248 rows x 18 columns]
# C:\Users\Raphael\AppData\Local\Temp\ipykernel_105580\2408166583.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   my_table = pd.read_sql(''' Select * from restaurant_data ''', conn)
